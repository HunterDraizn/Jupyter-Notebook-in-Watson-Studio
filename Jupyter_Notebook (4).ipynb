# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hunter Draizin**

# %% [markdown]
# I hope to enter into the feild of data science with specializations in mechine learning and ai.

# %% [markdown]
# *I am interesed in Data science becasue of the the innvotions that can be created. I belive data science is a key componante at the for front of modern descoveriys that will shape our world.*

# %% [markdown]
# ### This code adds 1 + 1 and prints the sum to the screen.

# %%
sum = (1 + 1)
print(sum)
# Out:
# 2

# %% [markdown]
# * one
# * two
# * three
# * four
# * five
# * six

# %%
List

# %% [markdown]
# Below are some of my favorite movies

# %% [markdown]
# ![download.jpg](attachment:ff72b3fd-0bbd-47ac-9a46-d950d9983185.jpg)![download.jpg](attachment:0713b6bb-1955-411d-a400-5bf171d476e3.jpg)![download.jpg](attachment:e073e539-4f08-44af-a454-27344b82cd67.jpg)
